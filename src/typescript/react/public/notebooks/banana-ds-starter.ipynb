# %% [markdown]
# # Banana Data Science Starter

# %%
samples = ['banana', 'plantain', 'apple']
print('sample_count:', len(samples))

# %%
scores = [0.12, 0.55, 0.91]
print('avg_score:', sum(scores) / len(scores))
